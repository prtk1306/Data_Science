# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())


b = bin(n)[2:]

max_count = 0
count = 0
for i in range(len(b)):

    if b[i] == '1': 
        count += 1
        if max_count < count:
            max_count = count
    else:
        count = 0

print(max_count)
# Out:
# 13
# 2
