# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

d = {}

for _ in range(n):
    arr = list(map(str, input().rstrip().split()))
    d[arr[0]] = arr[1]
    
for _ in range(n):
    q = input()
    try:
        print(q + '=' + d[q])
    except:
        print('Not found')
# Out:
# 3
# sam 99912222
# tom 11122222
# harry 12299933
# sam
# sam=99912222
# edward
# Not found
# harry
# harry=12299933
