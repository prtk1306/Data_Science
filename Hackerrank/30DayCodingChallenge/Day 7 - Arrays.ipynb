# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

n = int(input())
arr = list(map(int, input().rstrip().split()))
print(arr)

for i in range(len(arr)-1,-1,-1):
    print(arr[i], end=' ')
# Out:
# 3
# 1 2 3
# [1, 2, 3]
# 3 2 1
